# %% [markdown]
# # Assignment 5

# %% [markdown]
# I attempted to use the bounding boxes for cropping but they are wrong.

# %% [markdown]
# Team:
#
# - Bertan Karacora

# %% [markdown]
# Tasks:
#
# - a) Write **Convolutional** Variational Autoencoder (ConvVAE) for **CelebA** dataset: https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html
#     - Use Conv. layers for encoder and Transposed-Conv. layers for decoder.
#     - You are allowed to use one FC-layer in each module for the bottleneck, but it's not necessary
# - b) Investigate the importance of the KL-divergence weight. For this purpose, train multiple models using different weighting values and investigate how this value affects the generation performance.
# - c) Generate new images by sampling latent vectors, investigate latent space and visualize some interpolations.
# - d) Compare the models from a) and b)
#     - Qualitative comparison. Which images look better?
#     - Quantitative comparison between models using the Fréchet Inception Distance: https://arxiv.org/abs/1706.08500

# %% [markdown]
# ## Contents

# %% [markdown]
# - [x] [Setup](#setup)
#     - [x] [Config](#setup_config)
#     - [x] [Modules](#setup_modules)
#     - [x] [Paths and names](#setup_paths_and_names)
# - [x] [Data](#data)
#     - [x] [Visualization](#data_visualization)
#     - [x] [Discussion](#data_discussion)
# - [x] [Comparison of recurrent models](#comparison_of_recurrent_models)
#     - [x] [LSTM](#comparison_of_recurrent_models_lstm)
#     - [x] [Own LSTM](#comparison_of_recurrent_models_own_lstm)
#     - [x] [Own ConvLSTM](#comparison_of_recurrent_models_own_convlstm)
#     - [x] [GRU](#comparison_of_recurrent_models_gru)
#     - [x] [Discussion](#comparison_of_recurrent_models_discussion)
# - [x] [Comparison with 3D CNN](#comparison_with_3d_cnn)
#     - [x] [Results](#comparison_with_3d_cnn_results)
#     - [x] [Discussion](#comparison_with_3d_cnn_discussion)

# %% [markdown]
# ## Setup
# <a id="setup"></a>

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Config
# <a id="setup_config"></a>

# %%
import assignment.config as config
# Out:
# Config loaded from /home/user/karacora/lab-vision-systems-assignments/assignment_4/assignment/config.yaml

# %%
config.list_available()
# Out:
# ['kth_customlstm', 'kth_gru', 'kth_lstm', 'kth_lstmconv', 'kth_resnet3d']

# %% [markdown]
# ### Modules
# <a id="setup_modules"></a>

# %%
from pathlib import Path

from assignment.evaluation.evaluator import Evaluator
import assignment.libs.utils_checkpoints as utils_checkpoints

# %% [markdown]
# ### Paths and names
# <a id="setup_paths_and_names"></a>

# %%
name_exp_lstm = "kth_lstm"
name_exp_customlstm = "kth_customlstm"
name_exp_lstmconv = "kth_lstmconv"
name_exp_gru = "kth_gru"
name_exp_resnet3d = "kth_resnet3d"

path_dir_exp_lstm = Path(config._PATH_DIR_EXPS) / name_exp_lstm
path_dir_exp_customlstm = Path(config._PATH_DIR_EXPS) / name_exp_customlstm
path_dir_exp_lstmconv = Path(config._PATH_DIR_EXPS) / name_exp_lstmconv
path_dir_exp_gru = Path(config._PATH_DIR_EXPS) / name_exp_gru
path_dir_exp_resnet3d = Path(config._PATH_DIR_EXPS) / name_exp_resnet3d

# %% [markdown]
# ## Data
# <a id="data"></a>

# %% [markdown]
# ### Visualization
# <a id="data_visualization"></a>

# %% [markdown]
# #### Test dataset

# %% [markdown]
# ![Test dataset](experiments/kth_lstm/visualizations/Images_test.png)

# %% [markdown]
# #### Validate dataset

# %% [markdown]
# ![Validate dataset](experiments/kth_lstm/visualizations/Images_validate.png)

# %% [markdown]
# #### Train dataset

# %% [markdown]
# ![Train dataset](experiments/kth_lstm/visualizations/Images_train.png)

# %% [markdown]
# ### Discussion
# <a id="data_discussion"></a>

# %% [markdown]
# > Just some remarks:
# >
# > - The same data setup and the same augmentations are used in all experiments
# > - The already processed data is used (spit into frames, cut to $64 \times 64$)
# > - A sequence length of $15$ has been used
# > - The following augmentations are applied to the train dataset:
# >   - RandomHorizontalFlip
# >   - RandomRotation
# >   - ColorJitter
# >   - GaussianNoise (own implementation) + Clipping

# %% [markdown]
# ## Comparison of recurrent models
# <a id="comparison_of_recurrent_models"></a>

# %% [markdown]
# ### LSTM
# <a id="comparison_of_recurrent_models_lstm"></a>

# %% [markdown]
# ![LSTM Loss](experiments/kth_lstm/plots/Loss.png)
# ![LSTM Metrics](experiments/kth_lstm/plots/Metrics.png)

# %%
config.set_config_exp(path_dir_exp_lstm)
_, model, _, _ = utils_checkpoints.load(path_dir_exp_lstm / "checkpoints" / "final.pth")

evaluator = Evaluator(name_exp_lstm, model)
evaluator.evaluate()

print(f"Loss on test data: {evaluator.log["total"]["loss"]}")
print(f"Metrics on test data")
for name, metrics in evaluator.log["total"]["metrics"].items():
    print(f"    {name:<10}: {metrics}")
# Out:
# Config loaded from /home/user/karacora/lab-vision-systems-assignments/assignment_4/experiments/kth_lstm/config.yaml
# Initializing dataloader...
# Test dataset
# Dataset KTH
#     Number of datapoints: 4670
#     Path: /home/user/karacora/lab-vision-systems-assignments/assignment_4/data/kth
#     Split: test
#     Transform: ToDtype(
#   scale=True
#   (transform_tv): ToDtype(scale=True)
# )
#     Transform of target: None
# Initializing dataloader finished
# Initializing criterion...
# Initializing criterion finished
# Initializing measurers...
# Initializing measurers finished
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─CNN2dEncoder: 1-1                      [-1, 512]                 --
# |    └─Sequential: 2-1                   [-1, 512, 4, 4]           --
# |    |    └─BlockCNN2d: 3-1              [-1, 64, 32, 32]          1,792
# |    |    └─BlockCNN2d: 3-2              [-1, 128, 16, 16]         205,184
# |    |    └─BlockCNN2d: 3-3              [-1, 256, 8, 8]           819,968
# |    |    └─BlockCNN2d: 3-4              [-1, 512, 4, 4]           3,278,336
# |    └─Sequential: 2-2                   [-1, 512]                 --
# |    |    └─AdaptiveAvgPool2d: 3-5       [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-6                 [-1, 512]                 --
# |    |    └─Linear: 3-7                  [-1, 512]                 262,656
# ├─CNN2dEncoder: 1-2                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-3                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-8              [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-9              [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-10             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-11             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-4                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-12      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-13                [-1, 512]                 --
# |    |    └─Linear: 3-14                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-3                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-5                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-15             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-16             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-17             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-18             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-6                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-19      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-20                [-1, 512]                 --
# |    |    └─Linear: 3-21                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-4                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-7                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-22             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-23             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-24             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-25             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-8                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-26      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-27                [-1, 512]                 --
# |    |    └─Linear: 3-28                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-5                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-9                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-29             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-30             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-31             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-32             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-10                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-33      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-34                [-1, 512]                 --
# |    |    └─Linear: 3-35                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-6                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-11                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-36             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-37             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-38             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-39             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-12                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-40      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-41                [-1, 512]                 --
# |    |    └─Linear: 3-42                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-7                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-13                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-43             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-44             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-45             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-46             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-14                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-47      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-48                [-1, 512]                 --
# |    |    └─Linear: 3-49                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-8                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-15                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-50             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-51             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-52             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-53             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-16                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-54      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-55                [-1, 512]                 --
# |    |    └─Linear: 3-56                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-9                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-17                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-57             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-58             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-59             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-60             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-18                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-61      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-62                [-1, 512]                 --
# |    |    └─Linear: 3-63                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-10                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-19                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-64             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-65             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-66             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-67             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-20                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-68      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-69                [-1, 512]                 --
# |    |    └─Linear: 3-70                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-11                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-21                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-71             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-72             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-73             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-74             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-22                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-75      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-76                [-1, 512]                 --
# |    |    └─Linear: 3-77                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-12                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-23                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-78             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-79             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-80             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-81             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-24                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-82      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-83                [-1, 512]                 --
# |    |    └─Linear: 3-84                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-13                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-25                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-85             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-86             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-87             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-88             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-26                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-89      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-90                [-1, 512]                 --
# |    |    └─Linear: 3-91                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-14                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-27                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-92             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-93             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-94             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-95             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-28                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-96      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-97                [-1, 512]                 --
# |    |    └─Linear: 3-98                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-15                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-29                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-99             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-100            [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-101            [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-102            [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-30                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-103     [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-104               [-1, 512]                 --
# |    |    └─Linear: 3-105                [-1, 512]                 (recursive)
# ├─LSTM: 1-16                             [-1, 512]                 --
# |    └─ModuleList: 2                     []                        --
# |    |    └─LSTMCell: 3-106              [-1, 512]                 2,101,248
# |    |    └─LSTMCell: 3-107              [-1, 512]                 2,101,248
# |    |    └─LSTMCell: 3-108              [-1, 512]                 2,101,248
# |    |    └─LSTMCell: 3-109              [-1, 512]                 2,101,248
# |    |    └─LSTMCell: 3-110              [-1, 512]                 2,101,248
# |    |    └─LSTMCell: 3-111              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-112              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-113              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-114              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-115              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-116              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-117              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-118              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-119              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-120              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-121              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-122              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-123              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-124              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-125              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-126              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-127              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-128              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-129              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-130              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-131              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-132              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-133              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-134              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-135              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-136              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-137              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-138              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-139              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-140              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-141              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-142              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-143              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-144              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-145              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-146              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-147              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-148              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-149              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-150              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-151              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-152              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-153              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-154              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-155              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-156              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-157              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-158              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-159              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-160              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-161              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-162              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-163              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-164              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-165              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-166              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-167              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-168              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-169              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-170              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-171              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-172              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-173              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-174              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-175              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-176              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-177              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-178              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-179              [-1, 512]                 (recursive)
# |    |    └─LSTMCell: 3-180              [-1, 512]                 (recursive)
# ├─MLP: 1-17                              [-1, 6]                   --
# |    └─Sequential: 2-31                  [-1, 6]                   --
# |    |    └─Linear: 3-181                [-1, 256]                 131,328
# |    |    └─BatchNorm1d: 3-182           [-1, 256]                 512
# |    |    └─LeakyReLU: 3-183             [-1, 256]                 --
# |    |    └─Dropout: 3-184               [-1, 256]                 --
# |    |    └─Linear: 3-185                [-1, 6]                   1,542
# ==========================================================================================
# Total params: 15,207,558
# Trainable params: 15,207,558
# Non-trainable params: 0
# Total mult-adds (G): 9.91
# ==========================================================================================
# Input size (MB): 0.23
# Forward/backward pass size (MB): 7.53
# Params size (MB): 58.01
# Estimated Total Size (MB): 65.77
# ==========================================================================================
# Validating: Batch 070 | Loss 3.04440: 100%|██████████| 73/73 [00:10<00:00,  6.80it/s]
# Loss on test data: 1.759734357079806
# Metrics on test data
#     Accuracy  : 0.6143468950749464

# %% [markdown]
# ### Own LSTM
# <a id="comparison_of_recurrent_models_own_lstm"></a>

# %% [markdown]
# ![LSTM Loss](experiments/kth_customlstm/plots/Loss.png)
# ![LSTM Metrics](experiments/kth_customlstm/plots/Metrics.png)

# %%
config.set_config_exp(path_dir_exp_customlstm)
_, model, _, _ = utils_checkpoints.load(path_dir_exp_customlstm / "checkpoints" / "final.pth")

evaluator = Evaluator(name_exp_customlstm, model)
evaluator.evaluate()

print(f"Loss on test data: {evaluator.log["total"]["loss"]}")
print(f"Metrics on test data")
for name, metrics in evaluator.log["total"]["metrics"].items():
    print(f"    {name:<10}: {metrics}")
# Out:
# Config loaded from /home/user/karacora/lab-vision-systems-assignments/assignment_4/experiments/kth_customlstm/config.yaml
# Initializing dataloader...
# Test dataset
# Dataset KTH
#     Number of datapoints: 4670
#     Path: /home/user/karacora/lab-vision-systems-assignments/assignment_4/data/kth
#     Split: test
#     Transform: ToDtype(
#   scale=True
#   (transform_tv): ToDtype(scale=True)
# )
#     Transform of target: None
# Initializing dataloader finished
# Initializing criterion...
# Initializing criterion finished
# Initializing measurers...
# Initializing measurers finished
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─CNN2dEncoder: 1-1                      [-1, 512]                 --
# |    └─Sequential: 2-1                   [-1, 512, 4, 4]           --
# |    |    └─BlockCNN2d: 3-1              [-1, 64, 32, 32]          1,792
# |    |    └─BlockCNN2d: 3-2              [-1, 128, 16, 16]         205,184
# |    |    └─BlockCNN2d: 3-3              [-1, 256, 8, 8]           819,968
# |    |    └─BlockCNN2d: 3-4              [-1, 512, 4, 4]           3,278,336
# |    └─Sequential: 2-2                   [-1, 512]                 --
# |    |    └─AdaptiveAvgPool2d: 3-5       [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-6                 [-1, 512]                 --
# |    |    └─Linear: 3-7                  [-1, 512]                 262,656
# ├─CNN2dEncoder: 1-2                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-3                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-8              [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-9              [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-10             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-11             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-4                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-12      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-13                [-1, 512]                 --
# |    |    └─Linear: 3-14                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-3                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-5                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-15             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-16             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-17             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-18             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-6                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-19      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-20                [-1, 512]                 --
# |    |    └─Linear: 3-21                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-4                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-7                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-22             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-23             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-24             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-25             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-8                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-26      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-27                [-1, 512]                 --
# |    |    └─Linear: 3-28                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-5                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-9                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-29             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-30             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-31             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-32             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-10                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-33      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-34                [-1, 512]                 --
# |    |    └─Linear: 3-35                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-6                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-11                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-36             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-37             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-38             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-39             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-12                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-40      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-41                [-1, 512]                 --
# |    |    └─Linear: 3-42                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-7                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-13                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-43             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-44             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-45             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-46             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-14                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-47      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-48                [-1, 512]                 --
# |    |    └─Linear: 3-49                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-8                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-15                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-50             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-51             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-52             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-53             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-16                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-54      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-55                [-1, 512]                 --
# |    |    └─Linear: 3-56                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-9                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-17                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-57             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-58             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-59             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-60             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-18                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-61      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-62                [-1, 512]                 --
# |    |    └─Linear: 3-63                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-10                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-19                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-64             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-65             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-66             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-67             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-20                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-68      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-69                [-1, 512]                 --
# |    |    └─Linear: 3-70                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-11                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-21                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-71             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-72             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-73             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-74             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-22                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-75      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-76                [-1, 512]                 --
# |    |    └─Linear: 3-77                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-12                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-23                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-78             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-79             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-80             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-81             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-24                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-82      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-83                [-1, 512]                 --
# |    |    └─Linear: 3-84                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-13                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-25                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-85             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-86             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-87             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-88             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-26                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-89      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-90                [-1, 512]                 --
# |    |    └─Linear: 3-91                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-14                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-27                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-92             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-93             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-94             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-95             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-28                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-96      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-97                [-1, 512]                 --
# |    |    └─Linear: 3-98                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-15                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-29                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-99             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-100            [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-101            [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-102            [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-30                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-103     [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-104               [-1, 512]                 --
# |    |    └─Linear: 3-105                [-1, 512]                 (recursive)
# ├─LSTMCustom: 1-16                       [-1, 512]                 --
# |    └─ModuleList: 2                     []                        --
# |    |    └─CellLSTM: 3-106              [-1, 512]                 2,099,200
# |    |    └─CellLSTM: 3-107              [-1, 512]                 2,099,200
# |    |    └─CellLSTM: 3-108              [-1, 512]                 2,099,200
# |    |    └─CellLSTM: 3-109              [-1, 512]                 2,099,200
# |    |    └─CellLSTM: 3-110              [-1, 512]                 2,099,200
# |    |    └─CellLSTM: 3-111              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-112              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-113              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-114              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-115              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-116              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-117              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-118              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-119              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-120              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-121              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-122              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-123              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-124              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-125              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-126              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-127              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-128              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-129              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-130              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-131              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-132              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-133              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-134              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-135              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-136              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-137              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-138              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-139              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-140              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-141              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-142              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-143              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-144              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-145              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-146              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-147              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-148              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-149              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-150              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-151              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-152              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-153              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-154              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-155              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-156              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-157              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-158              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-159              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-160              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-161              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-162              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-163              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-164              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-165              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-166              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-167              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-168              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-169              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-170              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-171              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-172              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-173              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-174              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-175              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-176              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-177              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-178              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-179              [-1, 512]                 (recursive)
# |    |    └─CellLSTM: 3-180              [-1, 512]                 (recursive)
# ├─MLP: 1-17                              [-1, 6]                   --
# |    └─Sequential: 2-31                  [-1, 6]                   --
# |    |    └─Linear: 3-181                [-1, 256]                 131,328
# |    |    └─BatchNorm1d: 3-182           [-1, 256]                 512
# |    |    └─LeakyReLU: 3-183             [-1, 256]                 --
# |    |    └─Dropout: 3-184               [-1, 256]                 --
# |    |    └─Linear: 3-185                [-1, 6]                   1,542
# ==========================================================================================
# Total params: 15,197,318
# Trainable params: 15,197,318
# Non-trainable params: 0
# Total mult-adds (G): 10.07
# ==========================================================================================
# Input size (MB): 0.23
# Forward/backward pass size (MB): 7.59
# Params size (MB): 57.97
# Estimated Total Size (MB): 65.79
# ==========================================================================================
#   0%|          | 0/73 [00:00<?, ?it/s]/home/user/karacora/lab-vision-systems-assignments/.venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Validating: Batch 070 | Loss 1.13969: 100%|██████████| 73/73 [00:11<00:00,  6.41it/s]
# Loss on test data: 1.0212732574286247
# Metrics on test data
#     Accuracy  : 0.6910064239828694

# %% [markdown]
# ### Own ConvLSTM
# <a id="comparison_of_recurrent_models_own_convlstm"></a>

# %% [markdown]
# ![LSTM Loss](experiments/kth_lstmconv/plots/Loss.png)
# ![LSTM Metrics](experiments/kth_lstmconv/plots/Metrics.png)

# %%
config.set_config_exp(path_dir_exp_lstmconv)
_, model, _, _ = utils_checkpoints.load(path_dir_exp_lstmconv / "checkpoints" / "final.pth")

evaluator = Evaluator(name_exp_lstmconv, model)
evaluator.evaluate()

print(f"Loss on test data: {evaluator.log["total"]["loss"]}")
print(f"Metrics on test data")
for name, metrics in evaluator.log["total"]["metrics"].items():
    print(f"    {name:<10}: {metrics}")
# Out:
# Config loaded from /home/user/karacora/lab-vision-systems-assignments/assignment_4/experiments/kth_lstmconv/config.yaml
# Initializing dataloader...
# Test dataset
# Dataset KTH
#     Number of datapoints: 4670
#     Path: /home/user/karacora/lab-vision-systems-assignments/assignment_4/data/kth
#     Split: test
#     Transform: ToDtype(
#   scale=True
#   (transform_tv): ToDtype(scale=True)
# )
#     Transform of target: None
# Initializing dataloader finished
# Initializing criterion...
# Initializing criterion finished
# Initializing measurers...
# Initializing measurers finished
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─CNN2dEncoderSpatial: 1-1               [-1, 64, 2, 2]            --
# |    └─Sequential: 2-1                   [-1, 64, 2, 2]            --
# |    |    └─BlockCNN2d: 3-1              [-1, 32, 32, 32]          896
# |    |    └─BlockCNN2d: 3-2              [-1, 64, 16, 16]          51,392
# |    |    └─BlockCNN2d: 3-3              [-1, 128, 8, 8]           205,184
# |    |    └─BlockCNN2d: 3-4              [-1, 256, 4, 4]           819,968
# |    |    └─BlockCNN2d: 3-5              [-1, 64, 2, 2]            409,792
# ├─CNN2dEncoderSpatial: 1-2               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-2                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-6              [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-7              [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-8              [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-9              [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-10             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-3               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-3                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-11             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-12             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-13             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-14             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-15             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-4               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-4                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-16             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-17             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-18             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-19             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-20             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-5               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-5                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-21             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-22             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-23             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-24             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-25             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-6               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-6                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-26             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-27             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-28             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-29             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-30             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-7               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-7                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-31             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-32             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-33             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-34             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-35             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-8               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-8                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-36             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-37             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-38             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-39             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-40             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-9               [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-9                   [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-41             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-42             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-43             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-44             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-45             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-10              [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-10                  [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-46             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-47             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-48             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-49             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-50             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-11              [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-11                  [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-51             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-52             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-53             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-54             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-55             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-12              [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-12                  [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-56             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-57             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-58             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-59             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-60             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-13              [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-13                  [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-61             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-62             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-63             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-64             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-65             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-14              [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-14                  [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-66             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-67             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-68             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-69             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-70             [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoderSpatial: 1-15              [-1, 64, 2, 2]            (recursive)
# |    └─Sequential: 2-15                  [-1, 64, 2, 2]            (recursive)
# |    |    └─BlockCNN2d: 3-71             [-1, 32, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-72             [-1, 64, 16, 16]          (recursive)
# |    |    └─BlockCNN2d: 3-73             [-1, 128, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-74             [-1, 256, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-75             [-1, 64, 2, 2]            (recursive)
# ├─LSTMConv2d: 1-16                       [-1, 64, 2, 2]            --
# |    └─ModuleList: 2                     []                        --
# |    |    └─CellLSTMConv2d: 3-76         [-1, 64, 2, 2]            819,456
# |    |    └─CellLSTMConv2d: 3-77         [-1, 64, 2, 2]            819,456
# |    |    └─CellLSTMConv2d: 3-78         [-1, 64, 2, 2]            819,456
# |    |    └─CellLSTMConv2d: 3-79         [-1, 64, 2, 2]            819,456
# |    |    └─CellLSTMConv2d: 3-80         [-1, 64, 2, 2]            819,456
# |    |    └─CellLSTMConv2d: 3-81         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-82         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-83         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-84         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-85         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-86         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-87         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-88         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-89         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-90         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-91         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-92         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-93         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-94         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-95         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-96         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-97         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-98         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-99         [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-100        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-101        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-102        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-103        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-104        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-105        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-106        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-107        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-108        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-109        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-110        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-111        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-112        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-113        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-114        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-115        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-116        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-117        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-118        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-119        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-120        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-121        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-122        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-123        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-124        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-125        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-126        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-127        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-128        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-129        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-130        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-131        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-132        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-133        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-134        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-135        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-136        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-137        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-138        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-139        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-140        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-141        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-142        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-143        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-144        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-145        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-146        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-147        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-148        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-149        [-1, 64, 2, 2]            (recursive)
# |    |    └─CellLSTMConv2d: 3-150        [-1, 64, 2, 2]            (recursive)
# ├─CNN2dEncoder: 1-17                     [-1, 6]                   --
# |    └─Sequential: 2-16                  [-1, 64, 2, 2]            --
# |    |    └─BlockCNN2d: 3-151            [-1, 64, 2, 2]            102,592
# |    └─Sequential: 2-17                  [-1, 6]                   --
# |    |    └─AdaptiveAvgPool2d: 3-152     [-1, 64, 1, 1]            --
# |    |    └─Flatten: 3-153               [-1, 64]                  --
# |    |    └─Linear: 3-154                [-1, 6]                   390
# ==========================================================================================
# Total params: 5,687,494
# Trainable params: 5,687,494
# Non-trainable params: 0
# Total mult-adds (G): 2.89
# ==========================================================================================
# Input size (MB): 0.23
# Forward/backward pass size (MB): 3.81
# Params size (MB): 21.70
# Estimated Total Size (MB): 25.74
# ==========================================================================================
# Validating: Batch 070 | Loss 1.21665: 100%|██████████| 73/73 [00:05<00:00, 12.62it/s]
# Loss on test data: 0.9880165955494506
# Metrics on test data
#     Accuracy  : 0.7109207708779444

# %% [markdown]
# ### GRU
# <a id="comparison_of_recurrent_models_gru"></a>

# %% [markdown]
# ![GRU Loss](experiments/kth_gru/plots/Loss.png)
# ![GRU Metrics](experiments/kth_gru/plots/Metrics.png)

# %%
config.set_config_exp(path_dir_exp_gru)
_, model, _, _ = utils_checkpoints.load(path_dir_exp_gru / "checkpoints" / "final.pth")

evaluator = Evaluator(name_exp_gru, model)
evaluator.evaluate()

print(f"Loss on test data: {evaluator.log["total"]["loss"]}")
print(f"Metrics on test data")
for name, metrics in evaluator.log["total"]["metrics"].items():
    print(f"    {name:<10}: {metrics}")
# Out:
# Config loaded from /home/user/karacora/lab-vision-systems-assignments/assignment_4/experiments/kth_gru/config.yaml
# Initializing dataloader...
# Test dataset
# Dataset KTH
#     Number of datapoints: 4670
#     Path: /home/user/karacora/lab-vision-systems-assignments/assignment_4/data/kth
#     Split: test
#     Transform: ToDtype(
#   scale=True
#   (transform_tv): ToDtype(scale=True)
# )
#     Transform of target: None
# Initializing dataloader finished
# Initializing criterion...
# Initializing criterion finished
# Initializing measurers...
# Initializing measurers finished
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─CNN2dEncoder: 1-1                      [-1, 512]                 --
# |    └─Sequential: 2-1                   [-1, 512, 4, 4]           --
# |    |    └─BlockCNN2d: 3-1              [-1, 64, 32, 32]          1,792
# |    |    └─BlockCNN2d: 3-2              [-1, 128, 16, 16]         205,184
# |    |    └─BlockCNN2d: 3-3              [-1, 256, 8, 8]           819,968
# |    |    └─BlockCNN2d: 3-4              [-1, 512, 4, 4]           3,278,336
# |    └─Sequential: 2-2                   [-1, 512]                 --
# |    |    └─AdaptiveAvgPool2d: 3-5       [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-6                 [-1, 512]                 --
# |    |    └─Linear: 3-7                  [-1, 512]                 262,656
# ├─CNN2dEncoder: 1-2                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-3                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-8              [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-9              [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-10             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-11             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-4                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-12      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-13                [-1, 512]                 --
# |    |    └─Linear: 3-14                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-3                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-5                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-15             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-16             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-17             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-18             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-6                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-19      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-20                [-1, 512]                 --
# |    |    └─Linear: 3-21                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-4                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-7                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-22             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-23             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-24             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-25             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-8                   [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-26      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-27                [-1, 512]                 --
# |    |    └─Linear: 3-28                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-5                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-9                   [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-29             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-30             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-31             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-32             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-10                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-33      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-34                [-1, 512]                 --
# |    |    └─Linear: 3-35                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-6                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-11                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-36             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-37             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-38             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-39             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-12                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-40      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-41                [-1, 512]                 --
# |    |    └─Linear: 3-42                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-7                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-13                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-43             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-44             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-45             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-46             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-14                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-47      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-48                [-1, 512]                 --
# |    |    └─Linear: 3-49                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-8                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-15                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-50             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-51             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-52             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-53             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-16                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-54      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-55                [-1, 512]                 --
# |    |    └─Linear: 3-56                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-9                      [-1, 512]                 (recursive)
# |    └─Sequential: 2-17                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-57             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-58             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-59             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-60             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-18                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-61      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-62                [-1, 512]                 --
# |    |    └─Linear: 3-63                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-10                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-19                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-64             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-65             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-66             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-67             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-20                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-68      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-69                [-1, 512]                 --
# |    |    └─Linear: 3-70                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-11                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-21                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-71             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-72             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-73             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-74             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-22                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-75      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-76                [-1, 512]                 --
# |    |    └─Linear: 3-77                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-12                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-23                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-78             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-79             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-80             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-81             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-24                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-82      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-83                [-1, 512]                 --
# |    |    └─Linear: 3-84                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-13                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-25                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-85             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-86             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-87             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-88             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-26                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-89      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-90                [-1, 512]                 --
# |    |    └─Linear: 3-91                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-14                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-27                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-92             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-93             [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-94             [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-95             [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-28                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-96      [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-97                [-1, 512]                 --
# |    |    └─Linear: 3-98                 [-1, 512]                 (recursive)
# ├─CNN2dEncoder: 1-15                     [-1, 512]                 (recursive)
# |    └─Sequential: 2-29                  [-1, 512, 4, 4]           (recursive)
# |    |    └─BlockCNN2d: 3-99             [-1, 64, 32, 32]          (recursive)
# |    |    └─BlockCNN2d: 3-100            [-1, 128, 16, 16]         (recursive)
# |    |    └─BlockCNN2d: 3-101            [-1, 256, 8, 8]           (recursive)
# |    |    └─BlockCNN2d: 3-102            [-1, 512, 4, 4]           (recursive)
# |    └─Sequential: 2-30                  [-1, 512]                 (recursive)
# |    |    └─AdaptiveAvgPool2d: 3-103     [-1, 512, 1, 1]           --
# |    |    └─Flatten: 3-104               [-1, 512]                 --
# |    |    └─Linear: 3-105                [-1, 512]                 (recursive)
# ├─GRU: 1-16                              [-1, 512]                 --
# |    └─ModuleList: 2                     []                        --
# |    |    └─GRUCell: 3-106               [-1, 512]                 1,575,936
# |    |    └─GRUCell: 3-107               [-1, 512]                 1,575,936
# |    |    └─GRUCell: 3-108               [-1, 512]                 1,575,936
# |    |    └─GRUCell: 3-109               [-1, 512]                 1,575,936
# |    |    └─GRUCell: 3-110               [-1, 512]                 1,575,936
# |    |    └─GRUCell: 3-111               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-112               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-113               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-114               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-115               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-116               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-117               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-118               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-119               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-120               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-121               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-122               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-123               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-124               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-125               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-126               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-127               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-128               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-129               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-130               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-131               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-132               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-133               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-134               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-135               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-136               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-137               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-138               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-139               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-140               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-141               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-142               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-143               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-144               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-145               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-146               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-147               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-148               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-149               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-150               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-151               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-152               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-153               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-154               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-155               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-156               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-157               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-158               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-159               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-160               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-161               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-162               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-163               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-164               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-165               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-166               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-167               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-168               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-169               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-170               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-171               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-172               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-173               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-174               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-175               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-176               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-177               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-178               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-179               [-1, 512]                 (recursive)
# |    |    └─GRUCell: 3-180               [-1, 512]                 (recursive)
# ├─MLP: 1-17                              [-1, 6]                   --
# |    └─Sequential: 2-31                  [-1, 6]                   --
# |    |    └─Linear: 3-181                [-1, 256]                 131,328
# |    |    └─BatchNorm1d: 3-182           [-1, 256]                 512
# |    |    └─LeakyReLU: 3-183             [-1, 256]                 --
# |    |    └─Dropout: 3-184               [-1, 256]                 --
# |    |    └─Linear: 3-185                [-1, 6]                   1,542
# ==========================================================================================
# Total params: 12,580,998
# Trainable params: 12,580,998
# Non-trainable params: 0
# Total mult-adds (G): 9.87
# ==========================================================================================
# Input size (MB): 0.23
# Forward/backward pass size (MB): 7.53
# Params size (MB): 47.99
# Estimated Total Size (MB): 55.75
# ==========================================================================================
# Validating: Batch 070 | Loss 0.06183: 100%|██████████| 73/73 [00:04<00:00, 14.80it/s]
# Loss on test data: 1.3556768455616413
# Metrics on test data
#     Accuracy  : 0.6884368308351178

# %% [markdown]
# ### Discussion
# <a id="comparison_of_recurrent_models_discussion"></a>

# %% [markdown]
# > Implementation:
# >
# > - [Own LSTM and LSTM using Pytorch: assignment/models/lstm.py](assignment/models/lstm.py)
# > - [GRU using Pytorch: assignment/models/gru.py](assignment/models/gru.py)
# > - [RNN classifier wrapper: assignment/models/rnn.py](assignment/models/rnn.py)
# > - [CNN encoder: assignment/models/cnn.py](assignment/models/cnn.py)
# > - [MLP classifier: assignment/models/mlp.py](assignment/models/mlp.py)
# > - [Experiment recipes: assignment/configs/...](assignment/configs)
# > - [KTH dataset with automatic filtering of empty frames: assignment/datasets/kth.py](assignment/datasets/kth.py)
# > - [Results, tensorboard logs, visualizations, plots: experiments/...](experiments/)
# >
#
# > Some remarks:
# >
# > - A rather deep convolutional encoder did make the difference compared with earlier experiments not shown here.
# > - Despite weight regularization, learning rate scheduler, and data augmentationm there is overfitting in all experiments.
# > - Except for the LSTMConv the CNN encoder used the hidden dimensions $[64, 128, 256, 512]$
# > - All recurrent models comprise of 5 cells/layers with channel depth 512
# > - ReduceLROnPlateau scheduler and L2 regularization have been applied
# > - The accuracy is shown for the final model (although there might have been a higher accuracy in earlier epochs). This is the reason why the Pytorch LSTM has a lower accuracy. For reference, see the accuracy plots above (for the validation dataset). I will implement some functionality to savethe best performing checkpoint (besides the final one) until next assignment to fix this. The accuracies still give a good rough indication though.
# >
#
# > Results:
# >
# > Times are for one loop over the test dataset (4670 sequences of 15 frames each).
# > Training time is for a single epoch looping over the train set (4469 sequences).
#
#     | Model             | Accuracy | Training time | Inference time (still batched) | learnable params |
#     | :---------------- | :------: | :-----------: | :----------------------------: | ---------------: |
#     | LSTM (Pytorch)    |  0.614   |     17s       |             10s                |    15,207,558    |
#     | LSTM (Own)        |  0.691   |     17s       |             11s                |    15,197,318    |
#     | LSTMConv (Own)    |  0.710   |      8s       |              5s                |     5,687,494    |
#     | GRU               |  0.688   |     16s       |              4s                |    12,580,998    |
#
#
# > Observations/Conclusion:
# >
# > - My own implementation of the LSTM seems to behave very similar but not exactly the same as the Pytorch one
# > - The LSTMConv model performed best while requiring much less parameters than the other models and while being the fastest. This is similar to what we could observe when we compared 2D CNNs with MLPs. There is a great advantage in ackknowledging the spatial structure of an image instead of disregarding it completely.
# > - The GRU cells are lighter than the LSTM cells as it has less gates. Its performance is very similar.

# %% [markdown]
# ## Comparison with 3D CNN
# <a id="comparison_with_3d_cnn"></a>

# %% [markdown]
# ### Results
# <a id="comparison_with_3d_cnn_results"></a>

# %% [markdown]
# ![ResNet3d Loss](experiments/kth_resnet3d/plots/Loss.png)
# ![ResNet3d Metrics](experiments/kth_resnet3d/plots/Metrics.png)

# %%
config.set_config_exp(path_dir_exp_resnet3d)
_, model, _, _ = utils_checkpoints.load(path_dir_exp_resnet3d / "checkpoints" / "final.pth")

evaluator = Evaluator(name_exp_resnet3d, model)
evaluator.evaluate()

print(f"Loss on test data: {evaluator.log["total"]["loss"]}")
print(f"Metrics on test data")
for name, metrics in evaluator.log["total"]["metrics"].items():
    print(f"    {name:<10}: {metrics}")

# %% [markdown]
# ### Discussion
# <a id="comparison_with_3d_cnn_discussion"></a>

# %% [markdown]
# > Implementation:
# >
# > - [3D ResNet (mostly not own implementation, see code): assignment/models/resnet.py](assignment/models/resnet.py)
# >
#
#
# > Observations/Conclusion:
# >
# > - Didn't finish in time...

# %% [markdown]
# >
